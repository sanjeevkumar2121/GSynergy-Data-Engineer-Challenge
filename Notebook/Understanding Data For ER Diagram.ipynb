# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_clnd")
#df.printSchema()
display(df)
# Out:
# StatementMeta(, dc8d8902-0d4e-44bc-abdf-ca23ae8b584d, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e8bb12f2-d91c-40f7-835d-4c9ffcc844fe)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_hldy")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 6, Finished, Available, Finished)
# root
#  |-- hldy_id: string (nullable = true)
#  |-- hldy_label: string (nullable = true)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_invloc")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 7, Finished, Available, Finished)
# root
#  |-- loc: string (nullable = true)
#  |-- loc_label: string (nullable = true)
#  |-- loctype: string (nullable = true)
#  |-- loctype_label: string (nullable = true)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_invstatus")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 8, Finished, Available, Finished)
# root
#  |-- code_id: string (nullable = true)
#  |-- code_label: string (nullable = true)
#  |-- bckt_id: string (nullable = true)
#  |-- bckt_label: string (nullable = true)
#  |-- ownrshp_id: string (nullable = true)
#  |-- ownrshp_label: string (nullable = true)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_possite")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 9, Finished, Available, Finished)
# root
#  |-- site_id: string (nullable = true)
#  |-- site_label: string (nullable = true)
#  |-- subchnl_id: string (nullable = true)
#  |-- subchnl_label: string (nullable = true)
#  |-- chnl_id: string (nullable = true)
#  |-- chnl_label: string (nullable = true)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_pricestate")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 10, Finished, Available, Finished)
# root
#  |-- substate_id: string (nullable = true)
#  |-- substate_label: string (nullable = true)
#  |-- state_id: string (nullable = true)
#  |-- state_label: string (nullable = true)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_prod")
#df.printSchema()
display(df)
# Out:
# StatementMeta(, 4b853749-ee04-482d-99b3-10310093f94f, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 01cf6aea-45bc-441c-a3c3-41fddd670095)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/hier_rtlloc")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 12, Finished, Available, Finished)
# root
#  |-- str: string (nullable = true)
#  |-- str_label: string (nullable = true)
#  |-- dstr: string (nullable = true)
#  |-- dstr_label: string (nullable = true)
#  |-- rgn: string (nullable = true)
#  |-- rgn_label: string (nullable = true)

# %%
df = spark.read.format('parquet').option("inferSchema","true").load("Files/Stage 1 Final/fact_transactions")
df.printSchema()
# Out:
# StatementMeta(, 699afebc-3656-4492-ba35-14f2e1228c0b, 13, Finished, Available, Finished)
# root
#  |-- order_id: string (nullable = true)
#  |-- line_id: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- pos_site_id: string (nullable = true)
#  |-- sku_id: string (nullable = true)
#  |-- fscldt_id: string (nullable = true)
#  |-- price_substate_id: string (nullable = true)
#  |-- sales_units: string (nullable = true)
#  |-- sales_dollars: string (nullable = true)
#  |-- discount_dollars: string (nullable = true)
#  |-- original_order_id: string (nullable = true)
#  |-- original_line_id: string (nullable = true)
